# %%
import warnings
warnings.filterwarnings('ignore')

import os
dir_Path = 'C://Users//Acer'
os.chdir(dir_Path)

# %%
import pandas as pd 
# Local directory
Reviewdata = pd.read_csv('reviews1csv.csv')
Reviewdata=Reviewdata.astype(str)

# %%
#Removing columns
Reviewdata.drop(columns = ['paper', 'review','timespan','remarks','lan','assessment','orientation'], inplace = True)

# %%
Reviewdata.shape
# Out:
# (408, 5)

# %%
Reviewdata.head()
# Out:
#     id preliminary_decision confidence id.1  \
# 0  1.0               accept        4.0  1.0
# 1  nan                  nan        4.0  2.0
# 2  nan                  nan        5.0  3.0
# 3  2.0               accept        4.0  1.0
# 4  nan                  nan        4.0  2.0
#
#                                                 text
# 0  - The article deals with a contingent and very...
# 1  The article presents practical recommendations...
# 2  The topic is very interesting and a guide to i...
# 3  An experience of using ICT for academic collab...
# 4                                                nan

# %%
### Checking Missing values in the Data Set and printing the Percentage for Missing Values for Each Columns ###

count = Reviewdata.isnull().sum().sort_values(ascending=False)
percentage = ((Reviewdata.isnull().sum()/len(Reviewdata)*100)).sort_values(ascending=False)
missing_data = pd.concat([count, percentage], axis=1,
keys=['Count','Percentage'])

print('Count and percentage of missing values for the columns:')

missing_data
# Out:
# Count and percentage of missing values for the columns:
#                       Count  Percentage
# text                      0         0.0
# id.1                      0         0.0
# confidence                0         0.0
# preliminary_decision      0         0.0
# id                        0         0.0

# %%
### Checking for the Distribution of Default ###
import matplotlib.pyplot as plt
# %matplotlib inline
print('Percentage for default\n')
print(round(Reviewdata.preliminary_decision.value_counts(normalize=True)*100,5))
round(Reviewdata.preliminary_decision.value_counts(normalize=True)*100,2).plot(kind='histogram')
plt.title('Percentage Distributions by review type')
plt.show()
# Out:
# Percentage for default
#
# nan                57.84314
# accept             28.18627
# reject             11.76471
# probably reject     1.71569
# no decision         0.49020
# Name: preliminary_decision, dtype: float64
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-243-a15b56886b37> in <module>
#       4 print('Percentage for default\n')
#       5 print(round(Reviewdata.preliminary_decision.value_counts(normalize=True)*100,5))
# ----> 6 round(Reviewdata.preliminary_decision.value_counts(normalize=True)*100,2).plot(kind='histogram')
#       7 plt.title('Percentage Distributions by review type')
#       8 plt.show()
#
# ...

# %%
# Apply first level cleaning
import re
import string

#This function converts to lower-case, removes square bracket, removes numbers and punctuation
def text_clean_1(text):
    text = text.lower()
    text = re.sub('\[.*?\]', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\w*\d\w*', '', text)
    return text

cleaned1 = lambda x: text_clean_1(x)

# %%
Reviewdata=Reviewdata.dropna()

# %%
Reviewdata['cleaned_review'] = pd.DataFrame(Reviewdata.text.apply(cleaned1))
Reviewdata.head(10)
# Out:
#     id preliminary_decision confidence assessment id.1 lan orientation  \
# 0  1.0               accept        4.0        1.0  1.0  is         0.0
# 1  nan                  nan        4.0        1.0  2.0  is         1.0
# 2  nan                  nan        5.0        1.0  3.0  is         1.0
# 3  2.0               accept        4.0        2.0  1.0  is         1.0
# 4  nan                  nan        4.0        2.0  2.0  is         0.0
# 5  nan                  nan        4.0        2.0  3.0  is         0.0
# 6  3.0               accept        4.0        2.0  1.0  is         1.0
# 7  nan                  nan        3.0        2.0  2.0  on         1.0
# 8  nan                  nan        3.0        0.0  3.0  on        -1.0
# 9  4.0               accept        4.0        2.0  1.0  is         2.0
#
#                                                 text  \
# 0  - The article deals with a contingent and very...
# 1  The article presents practical recommendations...
# ...

# %%
# Apply a second round of cleaning
def text_clean_2(text):
    text = re.sub('[‘’“”…]', '', text)
    text = re.sub('\n', '', text)
    return text

cleaned2 = lambda x: text_clean_2(x)

# %%
Reviewdata['cleaned_review_new'] = pd.DataFrame(Reviewdata['cleaned_review'].apply(cleaned2))
Reviewdata.head(10)
# Out:
#     id preliminary_decision confidence assessment id.1 lan orientation  \
# 0  1.0               accept        4.0        1.0  1.0  is         0.0
# 1  nan                  nan        4.0        1.0  2.0  is         1.0
# 2  nan                  nan        5.0        1.0  3.0  is         1.0
# 3  2.0               accept        4.0        2.0  1.0  is         1.0
# 4  nan                  nan        4.0        2.0  2.0  is         0.0
# 5  nan                  nan        4.0        2.0  3.0  is         0.0
# 6  3.0               accept        4.0        2.0  1.0  is         1.0
# 7  nan                  nan        3.0        2.0  2.0  on         1.0
# 8  nan                  nan        3.0        0.0  3.0  on        -1.0
# 9  4.0               accept        4.0        2.0  1.0  is         2.0
#
#                                                 text  \
# 0  - The article deals with a contingent and very...
# 1  The article presents practical recommendations...
# ...

# %%
from sklearn.model_selection import train_test_split

Independent_var = Reviewdata.cleaned_review_new
Dependent_var = Reviewdata.preliminary_decision



IV_train, IV_test, DV_train, DV_test = train_test_split(Independent_var, Dependent_var, test_size = 0.3, random_state = 800)

print('IV_train :', len(IV_train))
print('IV_test  :', len(IV_test))
print('DV_train :', len(DV_train))
print('DV_test  :', len(DV_test))
# Out:
# IV_train : 285
# IV_test  : 123
# DV_train : 285
# DV_test  : 123

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression

tvec = TfidfVectorizer()
clf2 = LogisticRegression(solver = "lbfgs")


from sklearn.pipeline import Pipeline

# %%
model = Pipeline([('vectorizer',tvec),('classifier',clf2)])

model.fit(IV_train, DV_train)


from sklearn.metrics import confusion_matrix

predictions = model.predict(IV_test)

confusion_matrix(predictions, DV_test)
# Out:
# array([[ 2,  0,  0,  0],
#        [29, 81,  2,  9],
#        [ 0,  0,  0,  0],
#        [ 0,  0,  0,  0]], dtype=int64)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score

print("Accuracy : ", accuracy_score(predictions, DV_test))
print("Precision : ", precision_score(predictions, DV_test, average = 'weighted'))
print("Recall : ", recall_score(predictions, DV_test, average = 'weighted'))
# Out:
# Accuracy :  0.6747967479674797
# Precision :  0.9847888801468659
# Recall :  0.6747967479674797

# %%
input =["I am not satiesfied."]
result = model.predict(input)

print(result)
# Out:
# ['nan']
